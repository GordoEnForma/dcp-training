# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa
from keras.models import Sequential
from keras import optimizers
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
from keras.applications import Xception
# Out:
# c:\Users\gem_9\miniconda3\envs\dcp\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
base_model= Xception(include_top=False, weights="imagenet", input_shape=(256,256,3))

# %%
base_model.trainable = False
# for layer in base_model.layers:
#     layer.trainable = False

# %%
model= Sequential()
model.add(base_model)
model.add(Conv2D(64, (3, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(0.40))
model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(7, activation='softmax'))

# %%
data=pd.read_csv("HAM10000_metadata_kaggle.csv")
data.drop_duplicates(subset=['lesion_id'],inplace=True)
data['image_full_name']=data['image_id']+'.jpg'
X=data[['image_full_name','dx','lesion_id']]

# %%
from sklearn.model_selection import train_test_split
Y = X.pop('dx').to_frame()
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.25, random_state=42)

# %%
train=pd.concat([X_train,y_train],axis=1)
val=pd.concat([X_val,y_val],axis=1)
test=pd.concat([X_test,y_test],axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
encoder= LabelEncoder()
encoder.fit(val['dx'])
name_as_indexes_train=encoder.transform(val['dx']) 
val['label']=name_as_indexes_train

# %%
encoder=LabelEncoder()
encoder.fit(test['dx'])
name_as_indexes_test=encoder.transform(test['dx']) 
test['label']=name_as_indexes_test

# %%
from keras_preprocessing.image import ImageDataGenerator
train_generator = ImageDataGenerator(rescale = 1./255,
                                     rotation_range=10,  
                                     zoom_range = 0.1, 
                                     width_shift_range=0.0,  height_shift_range=0.0)

# %%
train_data= train_generator.flow_from_dataframe(dataframe=train,x_col="image_full_name",y_col="dx",
                                                batch_size=64,directory="ISIC2018_Task3_Training_Input",
                                                shuffle=True,class_mode="categorical",target_size=(256,256))
# Out:
# Found 4482 validated image filenames belonging to 7 classes.

# %%
test_generator=ImageDataGenerator(rescale = 1./255)

# %%
test_data= test_generator.flow_from_dataframe(dataframe=test,x_col="image_full_name",y_col="dx",
                                              directory="ISIC2018_Task3_Training_Input",
                                              shuffle=False,batch_size=1,class_mode=None,target_size=(256,256))
# Out:
# Found 1494 validated image filenames.

# %%
val_data=test_generator.flow_from_dataframe(dataframe=val,x_col="image_full_name",y_col="dx",
                                            directory="ISIC2018_Task3_Training_Input",
                                            batch_size=64,shuffle=False,class_mode="categorical",target_size=(256,256))
# Out:
# Found 1494 validated image filenames belonging to 7 classes.

# %%
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

learning_control = ReduceLROnPlateau(monitor='val_accuracy', patience=5, verbose=1, factor=.5, min_lr=0.00001)
# early_stopping = EarlyStopping(monitor='val_accuracy', patience=15, verbose=1, restore_best_weights=True)
model_checkpoint = ModelCheckpoint(filepath='Xception.h5', monitor='val_accuracy', verbose=1, save_best_only=True)

# %%
model.compile(optimizer=optimizers.Adam(learning_rate=0.001),
              loss="categorical_crossentropy", metrics=["accuracy", tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), tfa.metrics.F1Score(num_classes=7, average='macro')])
history = model.fit_generator(generator=train_data,
                    steps_per_epoch=train_data.samples//train_data.batch_size,
                    validation_data=val_data,
                    verbose=1,
                    validation_steps=val_data.samples//val_data.batch_size,
                    epochs=50, callbacks=[learning_control, model_checkpoint])
# Out:
# C:\Users\gem_9\AppData\Local\Temp\ipykernel_9196\1796597191.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(generator=train_data,
# Epoch 1/50
# 70/70 [==============================] - ETA: 0s - loss: 1.0871 - accuracy: 0.6919 - precision: 0.8138 - recall: 0.5946 - f1_score: 0.1475
# Epoch 1: val_accuracy improved from -inf to 0.74660, saving model to Xception.h5
# 70/70 [==============================] - 85s 1s/step - loss: 1.0871 - accuracy: 0.6919 - precision: 0.8138 - recall: 0.5946 - f1_score: 0.1475 - val_loss: 0.7319 - val_accuracy: 0.7466 - val_precision: 0.8653 - val_recall: 0.7072 - val_f1_score: 0.1287 - lr: 0.0010
# Epoch 2/50
# 70/70 [==============================] - ETA: 0s - loss: 0.8376 - accuracy: 0.7236 - precision: 0.8742 - recall: 0.6338 - f1_score: 0.1704
# Epoch 2: val_accuracy improved from 0.74660 to 0.76291, saving model to Xception.h5
# 70/70 [==============================] - 74s 1s/step - loss: 0.8376 - accuracy: 0.7236 - precision: 0.8742 - recall: 0.6338 - f1_score: 0.1704 - val_loss: 0.7111 - val_accuracy: 0.7629 - val_precision: 0.9229 - val_recall: 0.6420 - val_f1_score: 0.1868 - lr: 0.0010
# Epoch 3/50
# 70/70 [==============================] - ETA: 0s - loss: 0.8023 - accuracy: 0.7359 - precision: 0.8815 - recall: 0.6446 - f1_score: 0.1859
# Epoch 3: val_accuracy improved from 0.76291 to 0.76630, saving model to Xception.h5
# 70/70 [==============================] - 77s 1s/step - loss: 0.8023 - accuracy: 0.7359 - precision: 0.8815 - recall: 0.6446 - f1_score: 0.1859 - val_loss: 0.7131 - val_accuracy: 0.7663 - val_precision: 0.9257 - val_recall: 0.6433 - val_f1_score: 0.1898 - lr: 0.0010
# Epoch 4/50
# 70/70 [==============================] - ETA: 0s - loss: 0.7618 - accuracy: 0.7440 - precision: 0.8933 - recall: 0.6575 - f1_score: 0.2071
# Epoch 4: val_accuracy improved from 0.76630 to 0.77038, saving model to Xception.h5
# 70/70 [==============================] - 80s 1s/step - loss: 0.7618 - accuracy: 0.7440 - precision: 0.8933 - recall: 0.6575 - f1_score: 0.2071 - val_loss: 0.6711 - val_accuracy: 0.7704 - val_precision: 0.9005 - val_recall: 0.6766 - val_f1_score: 0.2086 - lr: 0.0010
# Epoch 5/50
# 70/70 [==============================] - ETA: 0s - loss: 0.7052 - accuracy: 0.7549 - precision: 0.8973 - recall: 0.6648 - f1_score: 0.2424
# Epoch 5: val_accuracy improved from 0.77038 to 0.77378, saving model to Xception.h5
# 70/70 [==============================] - 81s 1s/step - loss: 0.7052 - accuracy: 0.7549 - precision: 0.8973 - recall: 0.6648 - f1_score: 0.2424 - val_loss: 0.6773 - val_accuracy: 0.7738 - val_precision: 0.9167 - val_recall: 0.6651 - val_f1_score: 0.2076 - lr: 0.0010
# Epoch 6/50
# 70/70 [==============================] - ETA: 0s - loss: 0.7001 - accuracy: 0.7517 - precision: 0.8960 - recall: 0.6648 - f1_score: 0.2581
# Epoch 6: val_accuracy improved from 0.77378 to 0.77582, saving model to Xception.h5
# 70/70 [==============================] - 78s 1s/step - loss: 0.7001 - accuracy: 0.7517 - precision: 0.8960 - recall: 0.6648 - f1_score: 0.2581 - val_loss: 0.7298 - val_accuracy: 0.7758 - val_precision: 0.8915 - val_recall: 0.6977 - val_f1_score: 0.2500 - lr: 0.0010
# Epoch 7/50
# 70/70 [==============================] - ETA: 0s - loss: 0.6947 - accuracy: 0.7612 - precision: 0.8927 - recall: 0.6722 - f1_score: 0.2784
# Epoch 7: val_accuracy improved from 0.77582 to 0.78668, saving model to Xception.h5
# 70/70 [==============================] - 78s 1s/step - loss: 0.6947 - accuracy: 0.7612 - precision: 0.8927 - recall: 0.6722 - f1_score: 0.2784 - val_loss: 0.6404 - val_accuracy: 0.7867 - val_precision: 0.9119 - val_recall: 0.6889 - val_f1_score: 0.2985 - lr: 0.0010
# Epoch 8/50
# 70/70 [==============================] - ETA: 0s - loss: 0.6552 - accuracy: 0.7680 - precision: 0.9007 - recall: 0.6795 - f1_score: 0.3183
# Epoch 8: val_accuracy improved from 0.78668 to 0.78736, saving model to Xception.h5
# 70/70 [==============================] - 76s 1s/step - loss: 0.6552 - accuracy: 0.7680 - precision: 0.9007 - recall: 0.6795 - f1_score: 0.3183 - val_loss: 0.6410 - val_accuracy: 0.7874 - val_precision: 0.9096 - val_recall: 0.6902 - val_f1_score: 0.2814 - lr: 0.0010
# Epoch 9/50
# 70/70 [==============================] - ETA: 0s - loss: 0.6249 - accuracy: 0.7743 - precision: 0.9017 - recall: 0.6890 - f1_score: 0.3188
# Epoch 9: val_accuracy did not improve from 0.78736
# 70/70 [==============================] - 74s 1s/step - loss: 0.6249 - accuracy: 0.7743 - precision: 0.9017 - recall: 0.6890 - f1_score: 0.3188 - val_loss: 0.6432 - val_accuracy: 0.7860 - val_precision: 0.8911 - val_recall: 0.7174 - val_f1_score: 0.2329 - lr: 0.0010
# Epoch 10/50
# 70/70 [==============================] - ETA: 0s - loss: 0.6368 - accuracy: 0.7770 - precision: 0.8994 - recall: 0.7003 - f1_score: 0.3535
# Epoch 10: val_accuracy did not improve from 0.78736
# 70/70 [==============================] - 74s 1s/step - loss: 0.6368 - accuracy: 0.7770 - precision: 0.8994 - recall: 0.7003 - f1_score: 0.3535 - val_loss: 0.6301 - val_accuracy: 0.7785 - val_precision: 0.9013 - val_recall: 0.6889 - val_f1_score: 0.3285 - lr: 0.0010
# Epoch 11/50
# 70/70 [==============================] - ETA: 0s - loss: 0.6239 - accuracy: 0.7782 - precision: 0.9039 - recall: 0.7008 - f1_score: 0.3940
# Epoch 11: val_accuracy improved from 0.78736 to 0.79484, saving model to Xception.h5
# 70/70 [==============================] - 74s 1s/step - loss: 0.6239 - accuracy: 0.7782 - precision: 0.9039 - recall: 0.7008 - f1_score: 0.3940 - val_loss: 0.6226 - val_accuracy: 0.7948 - val_precision: 0.9131 - val_recall: 0.6923 - val_f1_score: 0.3668 - lr: 0.0010
# Epoch 12/50
# 70/70 [==============================] - ETA: 0s - loss: 0.5945 - accuracy: 0.7909 - precision: 0.9087 - recall: 0.7030 - f1_score: 0.4138
# Epoch 12: val_accuracy did not improve from 0.79484
# 70/70 [==============================] - 75s 1s/step - loss: 0.5945 - accuracy: 0.7909 - precision: 0.9087 - recall: 0.7030 - f1_score: 0.4138 - val_loss: 0.6466 - val_accuracy: 0.7812 - val_precision: 0.8867 - val_recall: 0.7072 - val_f1_score: 0.3597 - lr: 0.0010
# Epoch 13/50
# 70/70 [==============================] - ETA: 0s - loss: 0.5920 - accuracy: 0.7927 - precision: 0.9011 - recall: 0.7139 - f1_score: 0.4207
# Epoch 13: val_accuracy did not improve from 0.79484
# 70/70 [==============================] - 78s 1s/step - loss: 0.5920 - accuracy: 0.7927 - precision: 0.9011 - recall: 0.7139 - f1_score: 0.4207 - val_loss: 0.6391 - val_accuracy: 0.7745 - val_precision: 0.8916 - val_recall: 0.6875 - val_f1_score: 0.3864 - lr: 0.0010
# Epoch 14/50
# 70/70 [==============================] - ETA: 0s - loss: 0.5920 - accuracy: 0.7983 - precision: 0.8958 - recall: 0.7182 - f1_score: 0.4376
# Epoch 14: val_accuracy did not improve from 0.79484
# 70/70 [==============================] - 80s 1s/step - loss: 0.5920 - accuracy: 0.7983 - precision: 0.8958 - recall: 0.7182 - f1_score: 0.4376 - val_loss: 0.5992 - val_accuracy: 0.7942 - val_precision: 0.8981 - val_recall: 0.7249 - val_f1_score: 0.3746 - lr: 0.0010
# Epoch 15/50
# 70/70 [==============================] - ETA: 0s - loss: 0.5415 - accuracy: 0.8105 - precision: 0.9052 - recall: 0.7306 - f1_score: 0.4701
# Epoch 15: val_accuracy did not improve from 0.79484
# 70/70 [==============================] - 82s 1s/step - loss: 0.5415 - accuracy: 0.8105 - precision: 0.9052 - recall: 0.7306 - f1_score: 0.4701 - val_loss: 0.6159 - val_accuracy: 0.7914 - val_precision: 0.8973 - val_recall: 0.7120 - val_f1_score: 0.3941 - lr: 0.0010
# Epoch 16/50
# 70/70 [==============================] - ETA: 0s - loss: 0.5334 - accuracy: 0
50
# 70/70 [==============================] - ETA: 0s - loss: 0.3459 - accuracy: 0.8708 - precision: 0.9328 - recall: 0.8300 - f1_score: 0.6103
# Epoch 32: val_accuracy did not improve from 0.80639
# 70/70 [==============================] - 78s 1s/step - loss: 0.3459 - accuracy: 0.8708 - precision: 0.9328 - recall: 0.8300 - f1_score: 0.6103 - val_loss: 0.6565 - val_accuracy: 0.7921 - val_precision: 0.8631 - val_recall: 0.7541 - val_f1_score: 0.4436 - lr: 1.2500e-04
# Epoch 33/50
# 70/70 [==============================] - ETA: 0s - loss: 0.3326 - accuracy: 0.8780 - precision: 0.9325 - recall: 0.8377 - f1_score: 0.6241
# Epoch 33: val_accuracy did not improve from 0.80639
# 70/70 [==============================] - 77s 1s/step - loss: 0.3326 - accuracy: 0.8780 - precision: 0.9325 - recall: 0.8377 - f1_score: 0.6241 - val_loss: 0.6513 - val_accuracy: 0.7853 - val_precision: 0.8592 - val_recall: 0.7459 - val_f1_score: 0.4301 - lr: 1.2500e-04
# Epoch 34/50
# 70/70 [==============================] - ETA: 0s - loss: 0.3414 - accuracy: 0.8803 - precision: 0.9333 - recall: 0.8395 - f1_score: 0.6276
# Epoch 34: val_accuracy did not improve from 0.80639
# 70/70 [==============================] - 79s 1s/step - loss: 0.3414 - accuracy: 0.8803 - precision: 0.9333 - recall: 0.8395 - f1_score: 0.6276 - val_loss: 0.6538 - val_accuracy: 0.7989 - val_precision: 0.8652 - val_recall: 0.7629 - val_f1_score: 0.4363 - lr: 1.2500e-04
# Epoch 35/50
# 70/70 [==============================] - ETA: 0s - loss: 0.3159 - accuracy: 0.8902 - precision: 0.9365 - recall: 0.8481 - f1_score: 0.6499
# Epoch 35: val_accuracy did not improve from 0.80639
# 70/70 [==============================] - 77s 1s/step - loss: 0.3159 - accuracy: 0.8902 - precision: 0.9365 - recall: 0.8481 - f1_score: 0.6499 - val_loss: 0.6725 - val_accuracy: 0.7853 - val_precision: 0.8492 - val_recall: 0.7500 - val_f1_score: 0.4284 - lr: 1.2500e-04
# Epoch 36/50
# 70/70 [==============================] - ETA: 0s - loss: 0.3253 - accuracy: 0.8807 - precision: 0.9342 - recall: 0.8420 - f1_score: 0.6380
# Epoch 36: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 36: val_accuracy did not improve from 0.80639
# 70/70 [==============================] - 79s 1s/step - loss: 0.3253 - accuracy: 0.8807 - precision: 0.9342 - recall: 0.8420 - f1_score: 0.6380 - val_loss: 0.6710 - val_accuracy: 0.7901 - val_precision: 0.8619 - val_recall: 0.7507 - val_f1_score: 0.4369 - lr: 1.2500e-04
# Epoch 37/50
# 70/70 [==============================] - ETA: 0s - loss: 0.3212 - accuracy: 0.8830 - precision: 0.9355 - recall: 0.8409 - f1_score: 0.6338
# Epoch 37: val_accuracy did not improve from 0.80639
# 70/70 [==============================] - 81s 1s/step - loss: 0.3212 - accuracy: 0.8830 - precision: 0.9355 - recall: 0.8409 - f1_score: 0.6338 - val_loss: 0.6755 - val_accuracy: 0.7948 - val_precision: 0.8618 - val_recall: 0.7582 - val_f1_score: 0.4440 - lr: 6.2500e-05
# Epoch 38/50
# 70/70 [==============================] - ETA: 0s - loss: 0.3235 - accuracy: 0.8807 - precision: 0.9327 - recall: 0.8440 - f1_score: 0.6311
# Epoch 38: val_accuracy did not improve from 0.80639
# 70/70 [==============================] - 78s 1s/step - loss: 0.3235 - accuracy: 0.8807 - precision: 0.9327 - recall: 0.8440 - f1_score: 0.6311 - val_loss: 0.6727 - val_accuracy: 0.7948 - val_precision: 0.8595 - val_recall: 0.7520 - val_f1_score: 0.4526 - lr: 6.2500e-05
# Epoch 39/50
# 70/70 [==============================] - ETA: 0s - loss: 0.3119 - accuracy: 0.8907 - precision: 0.9355 - recall: 0.8531 - f1_score: 0.6555
# Epoch 39: val_accuracy did not improve from 0.80639
# 70/70 [==============================] - 75s 1s/step - loss: 0.3119 - accuracy: 0.8907 - precision: 0.9355 - recall: 0.8531 - f1_score: 0.6555 - val_loss: 0.6845 - val_accuracy: 0.7914 - val_precision: 0.8514 - val_recall: 0.7588 - val_f1_score: 0.4589 - lr: 6.2500e-05
# Epoch 40/50
# 70/70 [==============================] - ETA: 0s - loss: 0.
val_accuracy did not improve from 0.80639
# 70/70 [==============================] - 72s 1s/step - loss: 0.2987 - accuracy: 0.8898 - precision: 0.9412 - recall: 0.8483 - f1_score: 0.6457 - val_loss: 0.6893 - val_accuracy: 0.7887 - val_precision: 0.8538 - val_recall: 0.7575 - val_f1_score: 0.4418 - lr: 1.5625e-05
# Epoch 49/50
# 70/70 [==============================] - ETA: 0s - loss: 0.3005 - accuracy: 0.8889 - precision: 0.9375 - recall: 0.8549 - f1_score: 0.6406
# Epoch 49: val_accuracy did not improve from 0.80639
# 70/70 [==============================] - 71s 1s/step - loss: 0.3005 - accuracy: 0.8889 - precision: 0.9375 - recall: 0.8549 - f1_score: 0.6406 - val_loss: 0.6863 - val_accuracy: 0.7908 - val_precision: 0.8553 - val_recall: 0.7588 - val_f1_score: 0.4383 - lr: 1.5625e-05
# Epoch 50/50
# 70/70 [==============================] - ETA: 0s - loss: 0.3084 - accuracy: 0.8823 - precision: 0.9357 - recall: 0.8463 - f1_score: 0.6296
# Epoch 50: val_accuracy did not improve from 0.80639
# 70/70 [==============================] - 75s 1s/step - loss: 0.3084 - accuracy: 0.8823 - precision: 0.9357 - recall: 0.8463 - f1_score: 0.6296 - val_loss: 0.6872 - val_accuracy: 0.7914 - val_precision: 0.8555 - val_recall: 0.7602 - val_f1_score: 0.4431 - lr: 1.5625e-05

# %%
# Función para graficar la historia
import numpy as np
import matplotlib.pyplot as plt
EPOCAS = 50

def graficar(h):
    LOSS = 0
    ACCURACY = 1
    entrenamiento = np.zeros((2, EPOCAS))
    prueba = np.zeros((2, EPOCAS))
    entrenamiento[LOSS] = h.history['loss']  # loss de entrenamiento
    prueba[LOSS] = h.history['val_loss']    # loss de validación
    entrenamiento[ACCURACY] = h.history['accuracy']  # acc de entrenamiento
    prueba[ACCURACY] = h.history['val_accuracy']  # acc de validación
    epocas = range(1, EPOCAS+1)
    fig, axs = plt.subplots(1, 2, figsize=(15, 5))
    for i, label in zip((LOSS, ACCURACY), ('Loss', 'Accuracy')):
        axs[i].plot(epocas, entrenamiento[i], 'b-', label='Training '+label)
        axs[i].plot(epocas, prueba[i], 'y-', label='Validationg '+label)
        axs[i].set_title('Training & Validation ' + label)
        axs[i].set_xlabel('Epochs')
        axs[i].set_ylabel(label)
        axs[i].legend()
    plt.show()

graficar(history)

# %%
test_data.reset()
predictions = model.predict_generator(test_data, steps=test_data.samples/test_data.batch_size,verbose=1)
y_pred= np.argmax(predictions, axis=1)
# Out:
# C:\Users\gem_9\AppData\Local\Temp\ipykernel_9196\1044357436.py:2: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   predictions = model.predict_generator(test_data, steps=test_data.samples/test_data.batch_size,verbose=1)
# 1494/1494 [==============================] - 13s 8ms/step

# %%
from sklearn.metrics import confusion_matrix 
cm= confusion_matrix(name_as_indexes_test,y_pred)
print(cm)
# Out:
# [[ 14   7  11   0   6   9   0]
#  [  3  37  20   0   8  16   0]
#  [  3  10  82   0  21  39   0]
#  [  1   3   4   0   1   9   0]
#  [  1   4  11   0  47  57   0]
#  [  1   4  19   0  26 997   0]
#  [  0   2   3   0   0   8  10]]

# %%
print(name_as_indexes_test)
# Out:
# [5 2 5 ... 2 5 4]

# %%
from sklearn.metrics import classification_report
print(classification_report(name_as_indexes_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.30      0.40        47
#            1       0.55      0.44      0.49        84
#            2       0.55      0.53      0.54       155
#            3       0.00      0.00      0.00        18
#            4       0.43      0.39      0.41       120
#            5       0.88      0.95      0.91      1047
#            6       1.00      0.43      0.61        23
#
#     accuracy                           0.79      1494
#    macro avg       0.57      0.44      0.48      1494
# weighted avg       0.77      0.79      0.78      1494
# c:\Users\gem_9\miniconda3\envs\dcp\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gem_9\miniconda3\envs\dcp\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\gem_9\miniconda3\envs\dcp\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
